# %% [markdown]
# <a href="https://colab.research.google.com/github/rutujam24/AI-Projects/blob/main/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2

# %%
path_3ri = r"/content/3RI logo.png"
path_3 = r"/content/Example_3.jpg"
path_nature = r"/content/Nature.jpg"

# %%
img1 = cv2.imread(path_3ri)
img1
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img1_rgb = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img1_rgb
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img2 = cv2.imread(path_3)
img2
# Out:
# array([[[255, 255, 255],
#         [253, 253, 253],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [255, 255, 255],
#         [253, 253, 253],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img2_grayscale = cv2.imread(path_3,cv2.IMREAD_GRAYSCALE)
img2_grayscale
# Out:
# array([[255, 253, 255, 255, 252, 255, 252, 255, 253, 254, 255, 255, 251,
#         255, 254, 252, 255, 255, 255, 254, 252, 255, 254, 255, 255, 255,
#         255, 255],
#        [254, 255, 253, 254, 254, 255, 255, 254, 255, 255, 251, 255, 254,
#         254, 253, 255, 254, 255, 254, 255, 255, 254, 254, 255, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 254, 254, 255, 254, 253, 255, 253, 255, 255,
#         254, 253, 252, 255, 255, 252, 251, 255, 251, 255, 254, 255, 255,
#         255, 255],
#        [252, 255, 254, 185,  33,   2,   0,   1,   0,   1,   0,  30, 152,
#         255, 255, 255, 252, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255],
#        [255, 254, 255,  33,   0,   0,   2,   2,   0,   0,   2,   1,   3,
#           0,   0,   2,   0,  33, 151, 253, 253, 254, 255, 255, 255, 255,
#         255, 255],
#        [253, 254, 250, 138,   2,   0,   4,   0,   1,   0,   0,   0,   1,
# ...

# %%
img_nature = cv2.imread(path_nature)
img_nature
# Out:
# array([[[101, 117,  70],
#         [ 51,  67,  20],
#         [ 42,  58,  11],
#         ...,
#         [210, 180,  67],
#         [210, 180,  67],
#         [209, 179,  66]],
#
#        [[ 76,  92,  45],
#         [ 49,  65,  18],
#         [ 47,  63,  16],
#         ...,
#         [208, 180,  69],
#         [208, 180,  69],
#         [208, 180,  69]],
#
#        [[ 51,  67,  20],
#         [ 50,  66,  19],
#         [ 50,  66,  19],
#         ...,
#         [204, 181,  71],
#         [205, 182,  72],
#         [205, 182,  72]],
#
#        ...,
#
#        [[ 50,  61,  15],
#         [ 50,  61,  15],
#         [ 50,  61,  15],
#         ...,
#         [ 49,  71,  12],
#         [ 54,  76,  17],
#         [ 59,  81,  22]],
#
#        [[ 50,  61,  15],
#         [ 50,  61,  15],
#         [ 50,  61,  15],
#         ...,
#         [ 55,  77,  18],
#         [ 58,  80,  21],
#         [ 51,  73,  14]],
#
#        [[ 50,  61,  15],
#         [ 50,  61,  15],
#         [ 50,  61,  15],
# ...

# %%
img_nature_rgb = cv2.cvtColor(img_nature,cv2.COLOR_BGR2RGB)
img_nature_rgb
# Out:
# array([[[ 70, 117, 101],
#         [ 20,  67,  51],
#         [ 11,  58,  42],
#         ...,
#         [ 67, 180, 210],
#         [ 67, 180, 210],
#         [ 66, 179, 209]],
#
#        [[ 45,  92,  76],
#         [ 18,  65,  49],
#         [ 16,  63,  47],
#         ...,
#         [ 69, 180, 208],
#         [ 69, 180, 208],
#         [ 69, 180, 208]],
#
#        [[ 20,  67,  51],
#         [ 19,  66,  50],
#         [ 19,  66,  50],
#         ...,
#         [ 71, 181, 204],
#         [ 72, 182, 205],
#         [ 72, 182, 205]],
#
#        ...,
#
#        [[ 15,  61,  50],
#         [ 15,  61,  50],
#         [ 15,  61,  50],
#         ...,
#         [ 12,  71,  49],
#         [ 17,  76,  54],
#         [ 22,  81,  59]],
#
#        [[ 15,  61,  50],
#         [ 15,  61,  50],
#         [ 15,  61,  50],
#         ...,
#         [ 18,  77,  55],
#         [ 21,  80,  58],
#         [ 14,  73,  51]],
#
#        [[ 15,  61,  50],
#         [ 15,  61,  50],
#         [ 15,  61,  50],
# ...

# %% [markdown]
# ### Visualizing using  seaborn and matplotlib

# %%
img2_grayscale
# Out:
# array([[255, 253, 255, 255, 252, 255, 252, 255, 253, 254, 255, 255, 251,
#         255, 254, 252, 255, 255, 255, 254, 252, 255, 254, 255, 255, 255,
#         255, 255],
#        [254, 255, 253, 254, 254, 255, 255, 254, 255, 255, 251, 255, 254,
#         254, 253, 255, 254, 255, 254, 255, 255, 254, 254, 255, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 254, 254, 255, 254, 253, 255, 253, 255, 255,
#         254, 253, 252, 255, 255, 252, 251, 255, 251, 255, 254, 255, 255,
#         255, 255],
#        [252, 255, 254, 185,  33,   2,   0,   1,   0,   1,   0,  30, 152,
#         255, 255, 255, 252, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255],
#        [255, 254, 255,  33,   0,   0,   2,   2,   0,   0,   2,   1,   3,
#           0,   0,   2,   0,  33, 151, 253, 253, 254, 255, 255, 255, 255,
#         255, 255],
#        [253, 254, 250, 138,   2,   0,   4,   0,   1,   0,   0,   0,   1,
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.imshow(img2_grayscale)
plt.show()

# %% [markdown]
# cmap='hot'       # black → red → yellow → white
#
# cmap='coolwarm')  # blue → white → red
#
# cmap='viridis')   # purple → green → yellow
#
# cmap='plasma')    # purple → orange → yellow
#
# cmap='jet')       # blue → green → red (rainbow)
#
# cmap='Blues')     # white → dark blue
#
# cmap='magma')     # black → purple → orange → white

# %%
plt.imshow(img2_grayscale,cmap='gray')
plt.show()

# %% [markdown]
# 25 inches wide × 25 inches tall
#
#   (8, 6)Small — 5 to 10 columns(12, 10)Medium — 10 to 20 columns
#
#   (20, 20)Large — 20 to 30 columns(30, 30)Very large — 30+
#
#   columns or when you need all annotations clearly visible

# %%
plt.figure(figsize=(25,25))
sns.heatmap(img2_grayscale,annot=True,fmt='d')
plt.show()

# %%
img_3ri_grayscale = cv2.imread(path_3ri,cv2.IMREAD_GRAYSCALE)
img_3ri_grayscale
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.figure(figsize=(25,25))
sns.heatmap(img_3ri_grayscale,annot=True,fmt='d')
plt.show()

# %%
plt.figure(figsize=(30,30))
sns.heatmap(img_3ri_grayscale,annot=True,fmt='d')
plt.show()
